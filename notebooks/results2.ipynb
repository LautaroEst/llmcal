# %%
from results_utils import compute_results, plot_results

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
metrics = ["norm_error_rate", "norm_cross_entropy"]
bootstrap = 100
random_state = 42
df = compute_results(metrics, bootstrap, random_state, show_test=False)
df.loc[:,[c for c in df.columns if ":" not in c ]]
# Out:
# 100%|██████████| 48/48 [00:16<00:00,  2.84it/s]
#               dataset   size  num_samples  \
# 0             DBPedia  Large         2000
# 2             DBPedia  Large         2000
# 3             DBPedia  Large         2000
# 5             DBPedia  Large         2000
# 6             DBPedia  Large         2000
# 8             DBPedia  Large         2000
# 9             DBPedia  Large         2000
# 11            DBPedia  Large         2000
# 12  Medical Abstracts  Large         2000
# 14  Medical Abstracts  Large         2000
# 15  Medical Abstracts  Large         2000
# 17  Medical Abstracts  Large         2000
# 18  Medical Abstracts  Large         2000
# 20  Medical Abstracts  Large         2000
# 21  Medical Abstracts  Large         2000
# 23  Medical Abstracts  Large         2000
# 24             AGNews  Large         2000
# 26             AGNews  Large         2000
# 27             AGNews  Large         2000
# 29             AGNews  Large         2000
# 30             AGNews  Large         2000
# 32             AGNews  Large         2000
# 33             AGNews  Large         2000
# 35             AGNews  Large         2000
# 36          Banking77  Large        10000
# 38          Banking77  Large        10000
# 39          Banking77  Large        10000
# 41          Banking77  Large        10000
# 42          Banking77  Large        10000
# 44          Banking77  Large        10000
# 45          Banking77  Large        10000
# 47          Banking77  Large        10000
# 48              SST-2  Large         1000
# 50              SST-2  Large         1000
# 51              SST-2  Large         1000
# 53              SST-2  Large         1000
# 54              SST-2  Large         1000
# 56              SST-2  Large         1000
# 57              SST-2  Large         1000
# 59              SST-2  Large         1000
# 60       20NewsGroups  Large         8000
# 62       20NewsGroups  Large         8000
# 63       20NewsGroups  Large         8000
# 65       20NewsGroups  Large         8000
# 66       20NewsGroups  Large         8000
# 68       20NewsGroups  Large         8000
# 69       20NewsGroups  Large         8000
# 71       20NewsGroups  Large         8000
#
#                                    prompt  n_shots      model    base_method  \
# 0             basic_dbpedia_0-shot_litgpt        0  TinyLLAMA           LoRA
# 2             basic_dbpedia_0-shot_litgpt        0  TinyLLAMA           LoRA
# 3             basic_dbpedia_0-shot_litgpt        0  TinyLLAMA           LoRA
# 5             basic_dbpedia_0-shot_litgpt        0  TinyLLAMA           LoRA
# 6             basic_dbpedia_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 8             basic_dbpedia_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 9             basic_dbpedia_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 11            basic_dbpedia_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 12  basic_medical-abstracts_0-shot_litgpt        0  TinyLLAMA           LoRA
# 14  basic_medical-abstracts_0-shot_litgpt        0  TinyLLAMA           LoRA
# 15  basic_medical-abstracts_0-shot_litgpt        0  TinyLLAMA           LoRA
# 17  basic_medical-abstracts_0-shot_litgpt        0  TinyLLAMA           LoRA
# 18  basic_medical-abstracts_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 20  basic_medical-abstracts_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 21  basic_medical-abstracts_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 23  basic_medical-abstracts_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 24             basic_agnews_0-shot_litgpt        0  TinyLLAMA           LoRA
# 26             basic_agnews_0-shot_litgpt        0  TinyLLAMA           LoRA
# 27             basic_agnews_0-shot_litgpt        0  TinyLLAMA           LoRA
# 29             basic_agnews_0-shot_litgpt        0  TinyLLAMA           LoRA
# 30             basic_agnews_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 32             basic_agnews_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 33             basic_agnews_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 35             basic_agnews_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 36          basic_banking77_0-shot_litgpt        0  TinyLLAMA           LoRA
# 38          basic_banking77_0-shot_litgpt        0  TinyLLAMA           LoRA
# 39          basic_banking77_0-shot_litgpt        0  TinyLLAMA           LoRA
# 41          basic_banking77_0-shot_litgpt        0  TinyLLAMA           LoRA
# 42          basic_banking77_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 44          basic_banking77_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 45          basic_banking77_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 47          basic_banking77_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 48               basic_sst2_0-shot_litgpt        0  TinyLLAMA           LoRA
# 50               basic_sst2_0-shot_litgpt        0  TinyLLAMA           LoRA
# 51               basic_sst2_0-shot_litgpt        0  TinyLLAMA           LoRA
# 53               basic_sst2_0-shot_litgpt        0  TinyLLAMA           LoRA
# 54               basic_sst2_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 56               basic_sst2_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 57               basic_sst2_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 59               basic_sst2_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 60       basic_20newsgroups_0-shot_litgpt        0  TinyLLAMA           LoRA
# 62       basic_20newsgroups_0-shot_litgpt        0  TinyLLAMA           LoRA
# 63       basic_20newsgroups_0-shot_litgpt        0  TinyLLAMA           LoRA
# 65       basic_20newsgroups_0-shot_litgpt        0  TinyLLAMA           LoRA
# 66       basic_20newsgroups_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 68       basic_20newsgroups_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 69       basic_20newsgroups_0-shot_litgpt        0  TinyLLAMA  No Adaptation
# 71       basic_20newsgroups_0-shot_litgpt        0  TinyLLAMA  No Adaptation
#
#         cal_method       split norm_error_rate norm_cross_entropy
# 0   No Calibration       train   0.013 ± 0.001      0.017 ± 0.001
# 2   No Calibration  validation   0.009 ± 0.003      0.019 ± 0.005
# 3    Affine Vector       train   0.013 ± 0.001      0.092 ± 0.018
# 5    Affine Vector  validation   0.015 ± 0.004      0.107 ± 0.059
# 6   No Calibration       train   0.416 ± 0.006      1.427 ± 0.023
# 8   No Calibration  validation   0.401 ± 0.020      1.276 ± 0.066
# 9    Affine Vector       train   0.125 ± 0.003      0.141 ± 0.004
# 11   Affine Vector  validation   0.120 ± 0.011      0.137 ± 0.013
# 12  No Calibration       train   0.561 ± 0.009      0.605 ± 0.006
# 14  No Calibration  validation   0.587 ± 0.023      0.619 ± 0.017
# 15   Affine Vector       train   0.557 ± 0.009      0.595 ± 0.005
# 17   Affine Vector  validation   0.588 ± 0.023      0.609 ± 0.016
# 18  No Calibration       train   0.950 ± 0.012      2.768 ± 0.029
# 20  No Calibration  validation   1.016 ± 0.032      2.923 ± 0.085
# 21   Affine Vector       train   0.933 ± 0.010      0.948 ± 0.004
# 23   Affine Vector  validation   0.996 ± 0.029      0.960 ± 0.012
# 24  No Calibration       train   0.126 ± 0.004      0.198 ± 0.005
# 26  No Calibration  validation   0.134 ± 0.013      0.214 ± 0.020
# 27   Affine Vector       train   0.123 ± 0.004      0.193 ± 0.005
# 29   Affine Vector  validation   0.136 ± 0.013      0.210 ± 0.019
# 30  No Calibration       train   0.407 ± 0.006      0.970 ± 0.014
# 32  No Calibration  validation   0.410 ± 0.018      0.935 ± 0.043
# 33   Affine Vector       train   0.285 ± 0.006      0.398 ± 0.006
# 35   Affine Vector  validation   0.288 ± 0.016      0.391 ± 0.018
# 36  No Calibration       train   0.061 ± 0.003      0.043 ± 0.002
# 38  No Calibration  validation   0.106 ± 0.012      0.090 ± 0.013
# 39   Affine Vector       train   0.041 ± 0.002      0.039 ± 0.006
# 41   Affine Vector  validation   0.098 ± 0.011      0.183 ± 0.051
# 42  No Calibration       train   0.877 ± 0.004      1.788 ± 0.015
# 44  No Calibration  validation   0.892 ± 0.011      1.752 ± 0.040
# 45   Affine Vector       train   0.369 ± 0.005      0.323 ± 0.004
# 47   Affine Vector  validation   0.383 ± 0.015      0.342 ± 0.012
# 48  No Calibration       train   0.238 ± 0.007      0.374 ± 0.009
# 50  No Calibration  validation   0.253 ± 0.019      0.489 ± 0.038
# 51   Affine Vector       train   0.164 ± 0.006      0.283 ± 0.009
# 53   Affine Vector  validation   0.186 ± 0.021      0.347 ± 0.036
# 54  No Calibration       train   0.458 ± 0.009      0.739 ± 0.003
# 56  No Calibration  validation   0.319 ± 0.024      0.683 ± 0.010
# 57   Affine Vector       train   0.358 ± 0.009      0.517 ± 0.007
# 59   Affine Vector  validation   0.306 ± 0.027      0.523 ± 0.033
# 60  No Calibration       train   0.278 ± 0.004      0.265 ± 0.004
# 62  No Calibration  validation   0.303 ± 0.013      0.300 ± 0.011
# 63   Affine Vector       train   0.262 ± 0.004      0.248 ± 0.004
# 65   Affine Vector  validation   0.277 ± 0.012      0.282 ± 0.011
# 66  No Calibration       train   0.598 ± 0.005      0.792 ± 0.009
# 68  No Calibration  validation   0.593 ± 0.015      0.803 ± 0.025
# 69   Affine Vector       train   0.395 ± 0.005      0.396 ± 0.004
# 71   Affine Vector  validation   0.422 ± 0.016      0.413 ± 0.013

# %%
plot_results(df, metrics, width = 0.8, test = False)
