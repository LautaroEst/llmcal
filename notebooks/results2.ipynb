# %%
from results_utils import compute_results, plot_results

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
metrics = ["norm_error_rate", "norm_cross_entropy"]
bootstrap = 100
random_state = 42
df = compute_results(metrics, bootstrap, random_state, show_test=False)
df.loc[:,[c for c in df.columns if ":" not in c ]]
# Out:
# 100%|██████████| 60/60 [00:27<00:00,  2.20it/s]
#               dataset   size  num_samples       prompt  n_shots  \
# 0             DBPedia  Large         2000  Instruction        0
# 2             DBPedia  Large         2000  Instruction        0
# 3             DBPedia  Large         2000  Instruction        0
# 5             DBPedia  Large         2000  Instruction        0
# 6             DBPedia  Large         2000  Instruction        0
# 8             DBPedia  Large         2000  Instruction        0
# 9             DBPedia  Large         2000  Instruction        0
# 11            DBPedia  Large         2000  Instruction        0
# 12            DBPedia  Large         2000        Basic        0
# 14            DBPedia  Large         2000        Basic        0
# 15            DBPedia  Large         2000        Basic        0
# 17            DBPedia  Large         2000        Basic        0
# 18            DBPedia  Large         2000        Basic        0
# 20            DBPedia  Large         2000        Basic        0
# 21            DBPedia  Large         2000        Basic        0
# 23            DBPedia  Large         2000        Basic        0
# 24  Medical Abstracts  Large         2000        Basic        0
# 26  Medical Abstracts  Large         2000        Basic        0
# 27  Medical Abstracts  Large         2000        Basic        0
# 29  Medical Abstracts  Large         2000        Basic        0
# 30  Medical Abstracts  Large         2000        Basic        0
# 32  Medical Abstracts  Large         2000        Basic        0
# 33  Medical Abstracts  Large         2000        Basic        0
# 35  Medical Abstracts  Large         2000        Basic        0
# 36  Medical Abstracts  Large         2000  Instruction        0
# 38  Medical Abstracts  Large         2000  Instruction        0
# 39  Medical Abstracts  Large         2000  Instruction        0
# 41  Medical Abstracts  Large         2000  Instruction        0
# 42             AGNews  Large         2000        Basic        0
# 44             AGNews  Large         2000        Basic        0
# 45             AGNews  Large         2000        Basic        0
# 47             AGNews  Large         2000        Basic        0
# 48             AGNews  Large         2000        Basic        0
# 50             AGNews  Large         2000        Basic        0
# 51             AGNews  Large         2000        Basic        0
# 53             AGNews  Large         2000        Basic        0
# 54          Banking77  Large        10000  Instruction        0
# 56          Banking77  Large        10000  Instruction        0
# 57          Banking77  Large        10000  Instruction        0
# 59          Banking77  Large        10000  Instruction        0
# 60          Banking77  Large        10000  Instruction        0
# 62          Banking77  Large        10000  Instruction        0
# 63          Banking77  Large        10000  Instruction        0
# 65          Banking77  Large        10000  Instruction        0
# 66          Banking77  Large        10000        Basic        0
# 68          Banking77  Large        10000        Basic        0
# 69          Banking77  Large        10000        Basic        0
# 71          Banking77  Large        10000        Basic        0
# 72          Banking77  Large        10000        Basic        0
# 74          Banking77  Large        10000        Basic        0
# 75          Banking77  Large        10000        Basic        0
# 77          Banking77  Large        10000        Basic        0
# 78       20NewsGroups  Large         8000        Basic        0
# 80       20NewsGroups  Large         8000        Basic        0
# 81       20NewsGroups  Large         8000        Basic        0
# 83       20NewsGroups  Large         8000        Basic        0
# 84       20NewsGroups  Large         8000        Basic        0
# 86       20NewsGroups  Large         8000        Basic        0
# 87       20NewsGroups  Large         8000        Basic        0
# 89       20NewsGroups  Large         8000        Basic        0
#
#              model                method       split norm_error_rate  \
# 0   TinyLLAMA-Chat                  LoRA       train   0.015 ± 0.001
# 2   TinyLLAMA-Chat                  LoRA  validation   0.011 ± 0.003
# 3   TinyLLAMA-Chat  LoRA + Affine Vector       train   0.014 ± 0.001
# 5   TinyLLAMA-Chat  LoRA + Affine Vector  validation   0.015 ± 0.004
# 6   TinyLLAMA-Chat         No adaptation       train   0.635 ± 0.006
# 8   TinyLLAMA-Chat         No adaptation  validation   0.613 ± 0.022
# 9   TinyLLAMA-Chat         Affine Vector       train   0.124 ± 0.004
# 11  TinyLLAMA-Chat         Affine Vector  validation   0.122 ± 0.009
# 12       TinyLLAMA                  LoRA       train   0.013 ± 0.001
# 14       TinyLLAMA                  LoRA  validation   0.009 ± 0.003
# 15       TinyLLAMA  LoRA + Affine Vector       train   0.012 ± 0.001
# 17       TinyLLAMA  LoRA + Affine Vector  validation   0.009 ± 0.003
# 18       TinyLLAMA         No adaptation       train   0.416 ± 0.006
# 20       TinyLLAMA         No adaptation  validation   0.401 ± 0.020
# 21       TinyLLAMA         Affine Vector       train   0.128 ± 0.003
# 23       TinyLLAMA         Affine Vector  validation   0.112 ± 0.010
# 24       TinyLLAMA                  LoRA       train   0.561 ± 0.009
# 26       TinyLLAMA                  LoRA  validation   0.587 ± 0.023
# 27       TinyLLAMA  LoRA + Affine Vector       train   0.557 ± 0.009
# 29       TinyLLAMA  LoRA + Affine Vector  validation   0.588 ± 0.023
# 30       TinyLLAMA         No adaptation       train   0.950 ± 0.012
# 32       TinyLLAMA         No adaptation  validation   1.016 ± 0.032
# 33       TinyLLAMA         Affine Vector       train   0.933 ± 0.010
# 35       TinyLLAMA         Affine Vector  validation   0.996 ± 0.029
# 36  TinyLLAMA-Chat         No adaptation       train   1.080 ± 0.011
# 38  TinyLLAMA-Chat         No adaptation  validation   1.156 ± 0.030
# 39  TinyLLAMA-Chat         Affine Vector       train   1.062 ± 0.010
# 41  TinyLLAMA-Chat         Affine Vector  validation   1.125 ± 0.026
# 42       TinyLLAMA                  LoRA       train   0.126 ± 0.004
# 44       TinyLLAMA                  LoRA  validation   0.134 ± 0.013
# 45       TinyLLAMA  LoRA + Affine Vector       train   0.123 ± 0.004
# 47       TinyLLAMA  LoRA + Affine Vector  validation   0.136 ± 0.013
# 48       TinyLLAMA         No adaptation       train   0.407 ± 0.006
# 50       TinyLLAMA         No adaptation  validation   0.410 ± 0.018
# 51       TinyLLAMA         Affine Vector       train   0.285 ± 0.006
# 53       TinyLLAMA         Affine Vector  validation   0.288 ± 0.016
# 54  TinyLLAMA-Chat                  LoRA       train   0.092 ± 0.003
# 56  TinyLLAMA-Chat                  LoRA  validation   0.140 ± 0.012
# 57  TinyLLAMA-Chat  LoRA + Affine Vector       train   0.079 ± 0.003
# 59  TinyLLAMA-Chat  LoRA + Affine Vector  validation   0.125 ± 0.012
# 60  TinyLLAMA-Chat         No adaptation       train   0.919 ± 0.003
# 62  TinyLLAMA-Chat         No adaptation  validation   0.922 ± 0.011
# 63  TinyLLAMA-Chat         Affine Vector       train   0.411 ± 0.005
# 65  TinyLLAMA-Chat         Affine Vector  validation   0.417 ± 0.015
# 66       TinyLLAMA                  LoRA       train   0.061 ± 0.003
# 68       TinyLLAMA                  LoRA  validation   0.106 ± 0.012
# 69       TinyLLAMA  LoRA + Affine Vector       train   0.043 ± 0.002
# 71       TinyLLAMA  LoRA + Affine Vector  validation   0.097 ± 0.011
# 72       TinyLLAMA         No adaptation       train   0.877 ± 0.004
# 74       TinyLLAMA         No adaptation  validation   0.892 ± 0.011
# 75       TinyLLAMA         Affine Vector       train   0.369 ± 0.005
# 77       TinyLLAMA         Affine Vector  validation   0.383 ± 0.015
# 78       TinyLLAMA                  LoRA       train   0.278 ± 0.004
# 80       TinyLLAMA                  LoRA  validation   0.303 ± 0.013
# 81       TinyLLAMA  LoRA + Affine Vector       train   0.262 ± 0.004
# 83       TinyLLAMA  LoRA + Affine Vector  validation   0.277 ± 0.012
# 84       TinyLLAMA         No adaptation       train   0.598 ± 0.005
# 86       TinyLLAMA         No adaptation  validation   0.593 ± 0.015
# 87       TinyLLAMA         Affine Vector       train   0.395 ± 0.005
# 89       TinyLLAMA         Affine Vector  validation   0.422 ± 0.016
#
#    norm_cross_entropy
# 0       0.023 ± 0.001
# 2       0.019 ± 0.005
# 3       0.098 ± 0.017
# 5       0.031 ± 0.011
# 6       1.782 ± 0.026
# 8       1.625 ± 0.075
# 9       0.147 ± 0.004
# 11      0.150 ± 0.013
# 12      0.017 ± 0.001
# 14      0.019 ± 0.005
# 15      0.016 ± 0.001
# 17      0.018 ± 0.005
# 18      1.427 ± 0.023
# 20      1.276 ± 0.066
# 21      0.149 ± 0.003
# 23      0.140 ± 0.010
# 24      0.605 ± 0.006
# 26      0.619 ± 0.017
# 27      0.595 ± 0.005
# 29      0.609 ± 0.016
# 30      2.768 ± 0.029
# 32      2.923 ± 0.085
# 33      0.948 ± 0.004
# 35      0.960 ± 0.012
# 36      3.223 ± 0.030
# 38      3.404 ± 0.082
# 39      1.004 ± 0.002
# 41      1.018 ± 0.007
# 42      0.198 ± 0.005
# 44      0.214 ± 0.020
# 45      0.193 ± 0.005
# 47      0.210 ± 0.019
# 48      0.970 ± 0.014
# 50      0.935 ± 0.043
# 51      0.398 ± 0.006
# 53      0.391 ± 0.018
# 54      0.070 ± 0.002
# 56      0.104 ± 0.010
# 57      0.058 ± 0.002
# 59      0.102 ± 0.011
# 60      2.485 ± 0.019
# 62      2.399 ± 0.055
# 63      0.366 ± 0.004
# 65      0.373 ± 0.012
# 66      0.043 ± 0.002
# 68      0.090 ± 0.013
# 69      0.032 ± 0.001
# 71      0.083 ± 0.012
# 72      1.788 ± 0.015
# 74      1.752 ± 0.040
# 75      0.323 ± 0.004
# 77      0.342 ± 0.012
# 78      0.265 ± 0.004
# 80      0.300 ± 0.011
# 81      0.248 ± 0.004
# 83      0.282 ± 0.011
# 84      0.792 ± 0.009
# 86      0.803 ± 0.025
# 87      0.396 ± 0.004
# 89      0.413 ± 0.013

# %%
plot_results(df, metrics, width = 0.8, test = False)
